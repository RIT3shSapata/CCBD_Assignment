# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importing CSV Data

# %%
browser = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\browser.csv")

# %%
browser
# Out:
#     Unnamed: 0  %time   seconds  usecs/call  calls  errors      syscall
# 0            0  19.27  0.012226          27    444       0         mmap
# 1            1  15.36  0.009742          28    338       2        futex
# 2            2  10.37  0.006577          24    267       0         poll
# 3            3   8.94  0.005670          24    230      71       openat
# 4            4   6.21  0.003941          30    131       0       writev
# ..         ...    ...       ...         ...    ...     ...          ...
# 62          62   0.00  0.000000           0     23       0      madvise
# 63          63   0.00  0.000000           0      1       0   getsockopt
# 64          64   0.00  0.000000           0      1       0      symlink
# 65          65   0.00  0.000000           0      2       0  sigaltstack
# 66          66   0.00  0.000000           0      2       2       statfs
#
# [67 rows x 7 columns]

# %%
cat = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\cat.csv")

# %%
cat
# Out:
#     Unnamed: 0  %time  seconds  usecs/call  calls  errors     syscall
# 0            0    0.0      0.0           0      3       0        read
# 1            1    0.0      0.0           0      1       0       write
# 2            2    0.0      0.0           0      6       0       close
# 3            3    0.0      0.0           0      5       0       fstat
# 4            4    0.0      0.0           0      9       0        mmap
# 5            5    0.0      0.0           0      4       0    mprotect
# 6            6    0.0      0.0           0      2       0      munmap
# 7            7    0.0      0.0           0      3       0         brk
# 8            8    0.0      0.0           0      6       0     pread64
# 9            9    0.0      0.0           0      1       1      access
# 10          10    0.0      0.0           0      1       0      execve
# 11          11    0.0      0.0           0      2       1  arch_prctl
# 12          12    0.0      0.0           0      1       0   fadvise64
# 13          13    0.0      0.0           0      4       0      openat

# %%
echo = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\echo.csv")

# %%
echo
# Out:
#     Unnamed: 0  %time   seconds  usecs/call  calls  errors     syscall
# 0            0  20.18  0.000202          50      4       0    mprotect
# 1            1  19.28  0.000193          24      8       0        mmap
# 2            2  12.39  0.000124          24      5       0       close
# 3            3  11.59  0.000116          19      6       0     pread64
# 4            4   8.99  0.000090          30      3       0         brk
# 5            5   8.59  0.000086          21      4       0       fstat
# 6            6   6.99  0.000070          70      1       0       write
# 7            7   5.00  0.000050          25      2       1  arch_prctl
# 8            8   4.80  0.000048          48      1       0      munmap
# 9            9   2.20  0.000022           7      3       0      openat
# 10          10   0.00  0.000000           0      1       0        read
# 11          11   0.00  0.000000           0      1       1      access
# 12          12   0.00  0.000000           0      1       0      execve

# %%
ls = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\ls.csv")

# %%
ls
# Out:
#     Unnamed: 0  %time   seconds  usecs/call  calls  errors          syscall
# 0            0  22.07  0.000392          14     27       0             mmap
# 1            1  12.95  0.000230          20     11       0            close
# 2            2  12.16  0.000216          24      9       0         mprotect
# 3            3   8.16  0.000145          14     10       0            fstat
# 4            4   8.05  0.000143          15      9       0           openat
# 5            5   5.74  0.000102          14      7       0             read
# 6            6   3.66  0.000065          65      1       0            write
# 7            7   3.55  0.000063          31      2       2           statfs
# 8            8   2.76  0.000049          16      3       0              brk
# 9            9   2.70  0.000048          24      2       0            ioctl
# 10          10   2.70  0.000048           6      8       0          pread64
# 11          11   2.59  0.000046          23      2       0     rt_sigaction
# 12          12   2.20  0.000039          39      1       0           munmap
# 13          13   1.97  0.000035          17      2       2           access
# 14          14   1.91  0.000034          17      2       0       getdents64
# 15          15   1.75  0.000031          15      2       1       arch_prctl
# 16          16   1.30  0.000023          23      1       0  set_robust_list
# 17          17   1.30  0.000023          23      1       0        prlimit64
# 18          18   1.24  0.000022          22      1       0   rt_sigprocmask
# 19          19   1.24  0.000022          22      1       0  set_tid_address
# 20          20   0.00  0.000000           0      1       0           execve

# %%
mkdir = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\mkdir.csv")

# %%
mkdir
# Out:
#     Unnamed: 0  %time   seconds  usecs/call  calls  errors          syscall
# 0            0  18.36  0.000143          14     10       0            close
# 1            1  15.92  0.000124          15      8       0           openat
# 2            2  14.63  0.000114          16      7       0             read
# 3            3  14.63  0.000114         114      1       0            mkdir
# 4            4  12.84  0.000100          12      8       0            fstat
# 5            5  10.01  0.000078          26      3       0              brk
# 6            6   7.70  0.000060           2     27       0             mmap
# 7            7   5.91  0.000046          23      2       2           statfs
# 8            8   0.00  0.000000           0      9       0         mprotect
# 9            9   0.00  0.000000           0      1       0           munmap
# 10          10   0.00  0.000000           0      2       0     rt_sigaction
# 11          11   0.00  0.000000           0      1       0   rt_sigprocmask
# 12          12   0.00  0.000000           0      8       0          pread64
# 13          13   0.00  0.000000           0      2       2           access
# 14          14   0.00  0.000000           0      1       0           execve
# 15          15   0.00  0.000000           0      2       1       arch_prctl
# 16          16   0.00  0.000000           0      1       0  set_tid_address
# 17          17   0.00  0.000000           0      1       0  set_robust_list
# 18          18   0.00  0.000000           0      1       0        prlimit64

# %%
redis1 = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\redis1.csv")

# %%
redis1
# Out:
#     Unnamed: 0  %time    seconds  usecs/call    calls  errors  \
# 0            0  61.90  25.709109          25  1000196       0
# 1            1  19.58   8.130294          40   200585       0
# 2            2  17.56   7.295206          36   200015       0
# 3            3   0.91   0.379860          47     8017       0
# 4            4   0.01   0.005745          57      100     100
# 5            5   0.01   0.004210          36      116       0
# 6            6   0.01   0.004066          20      200       0
# 7            7   0.01   0.002660          26      100       0
# 8            8   0.01   0.002141          21      100       0
# 9            9   0.00   0.000008           0       15       0
# 10          10   0.00   0.000000           0        2       0
# 11          11   0.00   0.000000           0       65       0
# 12          12   0.00   0.000000           0       22       0
# 13          13   0.00   0.000000           0        5       0
# 14          14   0.00   0.000000           0        2       0
# 15          15   0.00   0.000000           0        4       0
# 16          16   0.00   0.000000           0        1       0
# 17          17   0.00   0.000000           0        8       0
# 18          18   0.00   0.000000           0        1       1
# 19          19   0.00   0.000000           0        1       0
# 20          20   0.00   0.000000           0        1       0
# 21          21   0.00   0.000000           0        1       1
# 22          22   0.00   0.000000           0        2       1
# 23          23   0.00   0.000000           0        1       0
# 24          24   0.00   0.000000           0        1       0
# 25          25   0.00   0.000000           0        1       0
# 26          26   0.00   0.000000           0       14       0
# 27          27   0.00   0.000000           0        1       0
# 28          28   0.00   0.000000           0        1       0
#
#               syscall
# 0           epoll_ctl
# 1               write
# 2                read
# 3          epoll_wait
# 4             connect
# 5               close
# 6               fcntl
# 7              socket
# 8          setsockopt
# 9               fstat
# 10               open
# 11               mmap
# 12           mprotect
# 13             munmap
# 14                brk
# 15       rt_sigaction
# 16     rt_sigprocmask
# 17            pread64
# 18             access
# 19            madvise
# 20             execve
# 21           readlink
# 22         arch_prctl
# 23  sched_getaffinity
# 24       epoll_create
# 25    set_tid_address
# 26             openat
# 27    set_robust_list
# 28          prlimit64

# %%
rmdir = pd.read_csv(r"C:\Users\suhas\Documents\College Projects\CCBD_Assignment\Parsed\rmdir.csv")

# %%
rmdir
# Out:
#     Unnamed: 0  %time  seconds  usecs/call  calls  errors     syscall
# 0            0    0.0      0.0           0      1       0        read
# 1            1    0.0      0.0           0      5       0       close
# 2            2    0.0      0.0           0      3       0       fstat
# 3            3    0.0      0.0           0      8       0        mmap
# 4            4    0.0      0.0           0      4       0    mprotect
# 5            5    0.0      0.0           0      1       0      munmap
# 6            6    0.0      0.0           0      3       0         brk
# 7            7    0.0      0.0           0      6       0     pread64
# 8            8    0.0      0.0           0      1       1      access
# 9            9    0.0      0.0           0      1       0      execve
# 10          10    0.0      0.0           0      1       0       rmdir
# 11          11    0.0      0.0           0      2       1  arch_prctl
# 12          12    0.0      0.0           0      3       0      openat
